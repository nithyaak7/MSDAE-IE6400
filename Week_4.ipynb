# %% [markdown]
# ## IE 6400 : Tutorial 1 - Data Wrangling and Basic Visualizations
#
# ### Northeastern University
#
# </br></br></br>

# %% [markdown]
# ## Imports

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Importing all datasets

# %%
penguins = pd.read_csv('https://raw.githubusercontent.com/qurat-azim/instructionaldatasets/main/data/penguins.csv')
cars = pd.read_csv('https://raw.githubusercontent.com/qurat-azim/instructionaldatasets/main/data/cars.csv')
municipalities = pd.read_csv('https://raw.githubusercontent.com/qurat-azim/instructionaldatasets/main/data/Mass_Municipalities.csv')
movies = pd.read_csv('https://raw.githubusercontent.com/qurat-azim/instructionaldatasets/main/data/imdb.csv')

# %%
penguins.head()
# Out:
#   species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen              39.1             18.7                181
# 1  Adelie  Torgersen              39.5             17.4                186
# 2  Adelie  Torgersen              40.3             18.0                195
# 3  Adelie  Torgersen              36.7             19.3                193
# 4  Adelie  Torgersen              39.3             20.6                190
#
#    body_mass_g     sex
# 0         3750    MALE
# 1         3800  FEMALE
# 2         3250  FEMALE
# 3         3450  FEMALE
# 4         3650    MALE

# %%
cars.head()
# Out:
#                         Name  Miles_per_Gallon  Cylinders  Displacement  \
# 0  chevrolet chevelle malibu              18.0          8         307.0
# 1          buick skylark 320              15.0          8         350.0
# 2         plymouth satellite              18.0          8         318.0
# 3              amc rebel sst              16.0          8         304.0
# 4                ford torino              17.0          8         302.0
#
#    Horsepower  Weight_in_lbs  Acceleration        Year Origin
# 0       130.0           3504          12.0  1970-01-01    USA
# 1       165.0           3693          11.5  1970-01-01    USA
# 2       150.0           3436          11.0  1970-01-01    USA
# 3       150.0           3433          12.0  1970-01-01    USA
# 4       140.0           3449          10.5  1970-01-01    USA

# %%
municipalities.head()
# Out:
#   Municipality  Type     County Per Capita Income Median Household Income
# 0       Weston  Town  Middlesex        105,217.00              192,563.00
# 1        Dover  Town    Norfolk         89,476.00              187,829.00
# 2    Lexington  Town  Middlesex         82,550.00              172,750.00
# 3     Carlisle  Town  Middlesex         77,585.00              160,034.00
# 4     Sherborn  Town  Middlesex         73,420.00              223,444.00

# %%
movies.head()
# Out:
#                Series_Title  Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption           1994           A  142 min
# 1             The Godfather           1972           A  175 min
# 2           The Dark Knight           2008          UA  152 min
# 3    The Godfather: Part II           1974           A  202 min
# 4              12 Angry Men           1957           U   96 min
#
#                   Genre  IMDB_Rating  Meta_score              Director  \
# 0                 Drama          9.3        80.0        Frank Darabont
# 1          Crime, Drama          9.2       100.0  Francis Ford Coppola
# 2  Action, Crime, Drama          9.0        84.0     Christopher Nolan
# 3          Crime, Drama          9.0        90.0  Francis Ford Coppola
# 4          Crime, Drama          9.0        96.0          Sidney Lumet
#
#             Star1           Star2          Star3           Star4  No_of_Votes  \
# ...

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Series_Title   1000 non-null   object
#  1   Released_Year  1000 non-null   int64
#  2   Certificate    899 non-null    object
#  3   Runtime        1000 non-null   object
#  4   Genre          1000 non-null   object
#  5   IMDB_Rating    1000 non-null   float64
#  6   Meta_score     843 non-null    float64
#  7   Director       1000 non-null   object
#  8   Star1          1000 non-null   object
#  9   Star2          1000 non-null   object
#  10  Star3          1000 non-null   object
#  11  Star4          1000 non-null   object
#  12  No_of_Votes    1000 non-null   int64
#  13  Gross          831 non-null    float64
# dtypes: float64(3), int64(2), object(9)
# memory usage: 109.5+ KB

# %%
penguins.describe()
# Out:
#        culmen_length_mm  culmen_depth_mm  flipper_length_mm  body_mass_g
# count        342.000000       342.000000         342.000000   342.000000
# mean          43.921930        17.151170         200.915205  4201.754386
# std            5.459584         1.974793          14.061714   801.954536
# min           32.100000        13.100000         172.000000  2700.000000
# 25%           39.225000        15.600000         190.000000  3550.000000
# 50%           44.450000        17.300000         197.000000  4050.000000
# 75%           48.500000        18.700000         213.000000  4750.000000
# max           59.600000        21.500000         231.000000  6300.000000

# %% [markdown]
# ## Data Wrangling and Manipulation Practice

# %% [markdown]
# #### Activity 1:
# For the movies dataset, do the following:
#
# - Filter rows with movies whose genre is `Crime, Drama`
# - How many movies have more than a million votes

# %%
movies[movies['Genre'] == "Crime, Drama"]
# Out:
#                     Series_Title  Released_Year Certificate  Runtime  \
# 1                  The Godfather           1972           A  175 min
# 3         The Godfather: Part II           1974           A  202 min
# 4                   12 Angry Men           1957           U   96 min
# 6                   Pulp Fiction           1994           A  154 min
# 22                Cidade de Deus           2002           A  130 min
# 71   Once Upon a Time in America           1984           A  229 min
# 108                     Scarface           1983           A  170 min
# 111                  Taxi Driver           1976           A  114 min
# 165                       Casino           1995           A  178 min
# 180        To Kill a Mockingbird           1962           U  129 min
# 257                     La haine           1995          UA   98 min
# 288               Cool Hand Luke           1967           A  127 min
# 299       Les quatre cents coups           1959         NaN   99 min
# ...

# %%
len(movies['No_of_Votes'] > 1000000)
# Out:
# 1000

# %% [markdown]
# #### Activity 2:
#
# For the movies dataset, show the average number of votes for movies for each of the released year. Display the mean votes and released year only.

# %%
movies.groupby('Released_Year', as_index=False)['No_of_Votes'].mean()
# Out:
#     Released_Year   No_of_Votes
# 0            1920  5.742800e+04
# 1            1921  1.133140e+05
# 2            1922  8.879400e+04
# 3            1924  4.198500e+04
# 4            1925  7.705350e+04
# ..            ...           ...
# 95           2017  2.586361e+05
# 96           2018  2.195192e+05
# 97           2019  2.601555e+05
# 98           2020  8.412700e+04
# 99           3010  2.067042e+06
#
# [100 rows x 2 columns]

# %% [markdown]
# #### Activity 3:
#
# For the penguins dataset, identify the average body mass and flipper lengths of each species.

# %%
penguins.groupby('species', as_index=False)[['body_mass_g','flipper_length_mm']].mean()
# Out:
#      species  body_mass_g  flipper_length_mm
# 0     Adelie  3700.662252         189.953642
# 1  Chinstrap  3733.088235         195.823529
# 2     Gentoo  5076.016260         217.186992

# %% [markdown]
# #### Practice Problem 1:
# Wrangle the data to make a new column in the cars dataframe called `Fuel_efficiency` with five categories. The categories should follow from values in the `Miles_per_Gallon` column in the following way:
# - If `Miles_per_Gallon` is less than 11.0, the `Fuel_efficiency` should be `Very Low`.
# - If `Miles_per_Gallon` is less than 18.0 and greater than or equal to 11.0, the `Fuel_efficiency` should be `Low`.
# - If `Miles_per_Gallon` is less than 25.0 and greater than or equal to 18.0, the `Fuel_efficiency` should be `Average`.
# - If `Miles_per_Gallon` is less than 30.0 and greater than or equal to 25.0, the `Fuel_efficiency` should be `High`.
# - If `Miles_per_Gallon` is greater than or equal to 30.0, the `Fuel_efficiency` should be `Very High`.
#
# Now create a heatmap with `Cylinders` on the x-axis and `Fuel_efficieny` on the y-axis to report `Horsepower`. What general treand do you observe, and how many cylinders would you recommend from the most fuel efficient cars to obtain maximum horsepower.

# %%
def categorize(value):
    if value < 11.0:
        return 'Very Low'
    elif value < 18.0 and value >= 11.0:
        return 'Low'
    elif value < 25.0 and value >= 18.0:
        return 'Average'
    elif value < 30.0 and value >= 25.0:
        return 'High'
    else: 
        return 'Very High'

cars['Fuel_efficiency'] = cars['Miles_per_Gallon'].apply(categorize)
cars.head()
# Out:
#                         Name  Miles_per_Gallon  Cylinders  Displacement  \
# 0  chevrolet chevelle malibu              18.0          8         307.0
# 1          buick skylark 320              15.0          8         350.0
# 2         plymouth satellite              18.0          8         318.0
# 3              amc rebel sst              16.0          8         304.0
# 4                ford torino              17.0          8         302.0
#
#    Horsepower  Weight_in_lbs  Acceleration        Year Origin Fuel_efficiency
# 0       130.0           3504          12.0  1970-01-01    USA         Average
# 1       165.0           3693          11.5  1970-01-01    USA             Low
# 2       150.0           3436          11.0  1970-01-01    USA         Average
# 3       150.0           3433          12.0  1970-01-01    USA             Low
# 4       140.0           3449          10.5  1970-01-01    USA             Low

# %% [markdown]
# ## Data Visualization Practice

# %% [markdown]
# #### Activity 4:
#
# For the cars dataset, create a histogram showing distibution of `Miles_per_Gallon`

# %%
cars['Miles_per_Gallon'].plot(kind='hist',bins=5, edgecolor='black')
plt.title("Histogram of Miles Per Gallon")
plt.xlabel("Miles Per Gallon")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# #### Activity 5:
#
# For the penguins dataset, how are the numeric features correlated with each other? Show using a heatmap.

# %%
corr_matrix=penguins.corr(numeric_only = True)
sns.heatmap(corr_matrix,annot=True,cmap='coolwarm')
plt.title("Heatmap of the correlation matrix")
plt.show()

# %% [markdown]
# #### Activity 6:
#
# For the movies dataset, show how `IMDB_Rating` varies as `Meta_score` changes. Visualize using a scatterplot.

# %%
corr_value=movies['IMDB_Rating'].corr(movies['Meta_score'])
sns.scatterplot(movies,x='IMDB_Rating',y='Meta_score',alpha=0.5)
# Out:
# <Axes: xlabel='IMDB_Rating', ylabel='Meta_score'>

# %% [markdown]
# #### Activity 7:
# Create a density plot `Weight_in_lbs` of the cars dataset.

# %%
sns.kdeplot(cars['Weight_in_lbs'],fill=True)
# Out:
# <Axes: xlabel='Weight_in_lbs', ylabel='Density'>

# %%
sns.displot(cars,x='Weight_in_lbs')

# %%
sns.displot(cars,x='Weight_in_lbs',kind='kde')

# %% [markdown]
# #### Activity 8:
#
# Show the distribution of the body masses of male penguins using a boxplot.

# %%
male_penguins=penguins[penguins['sex']=='MALE']
male_penguins.head()
sns.boxplot(male_penguins,x='body_mass_g',hue='species')
# Out:
# <Axes: xlabel='body_mass_g'>

# %% [markdown]
# #### Practice Problem 2:
#
# Create a scatterplot for `Weight_in_lbs` against `Miles_per_Gallon` for the cars dataset. Colour the points by `Origin`.

# %%
sns.scatterplot(cars,x='Weight_in_lbs',y='Miles_per_Gallon',hue='Origin')
# Out:
# <Axes: xlabel='Weight_in_lbs', ylabel='Miles_per_Gallon'>

# %% [markdown]
# Based on the above chart, we can infer that the Japanese cars are the lightest in the dataset and they are also the car that gives maximum mileage.
